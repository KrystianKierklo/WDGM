# %%
from Lab03.Image import Image
from filters import *
from Lab08.Opencv import *

obraz2 = Image("C:/Users/Krystian/Documents/GitHub/WDGM/Labs/Images/book.jpg")
obraz3 = Image("C:/Users/Krystian/Documents/GitHub/WDGM/Labs/Images/book.jpg")


# obraz2.to_gray()
# obraz2.conv_2d(filtr_tozsamosciowy, prefix_tozsamosciowy)
# obraz2.align_image(True)
# obraz2.threshold(19)
# obraz2.show_img()


obraz3.threshold(6)
obraz3.show_img()
